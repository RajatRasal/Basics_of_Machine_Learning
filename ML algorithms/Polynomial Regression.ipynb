# %% [markdown]
# # Polynomial Regression

# %%
# %matplotlib inline
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from random import randint

learning_rate = 0.01
training_epochs = 40

# %%
data_points = 100
# 6 degree polynomial
poly_coefficients = [1, 2, 3, 4, 5, 6]
x_train = np.linspace(-1, 1, data_points)
y_train = 0
for i in range(len(poly_coefficients)):
    y_train += poly_coefficients[i] * np.power(x_train, i)
y_train += np.random.randn(len(y_train)) * 0.5

# %%
plt.scatter(x_train, y_train)
plt.show()

# %%
X = tf.placeholder("float")
Y = tf.placeholder("float")

# %%
model = lambda X, w : tf.add_n([tf.multiply(w[i], tf.pow(X, i)) for i in range(len(poly_coefficients))])

# %%
w = tf.Variable([0.] * len(poly_coefficients), name="parameters")
y_model = model(X, w)

# %%
cost = tf.square(Y-y_model)
train_op = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    
    for epoch in range(training_epochs):
        for (x, y) in zip(x_train, y_train):
            print(x, y)
            sess.run(train_op, feed_dict={X: x, Y: y})
        
    w = sess.run(w)
    print(w)
# Out:
# -1.0 -2.42650504290891
# -0.9797979797979798 -3.5103310252079805
# -0.9595959595959596 -3.017881503807361
# -0.9393939393939394 -2.4650120127068633
# -0.9191919191919192 -2.0922899343578854
# -0.898989898989899 -1.7310603718614739
# -0.8787878787878788 -1.3510812745639977
# -0.8585858585858586 -1.3603763389068757
# -0.8383838383838383 -0.8483128676828535
# -0.8181818181818181 -0.9127036851463028
# -0.797979797979798 -0.5663988522608439
# -0.7777777777777778 0.0930726208043342
# -0.7575757575757576 -0.6187523731225426
# -0.7373737373737373 -0.13326476455983724
# -0.7171717171717171 -0.4072849002257727
# -0.696969696969697 -0.6268011619751431
# -0.6767676767676767 0.39658534732328804
# -0.6565656565656566 0.23893622742164253
# -0.6363636363636364 -0.1228266489642357
# -0.6161616161616161 -0.5313067853702493
# -0.5959595959595959 -0.407214145425953
# -0.5757575757575757 1.1092609798297504
# -0.5555555555555556 1.1773941098059928
# -0.5353535353535352 0.6316903347115261
# ...

# %%
plt.scatter(x_train, y_train)
y_learned = 0
for i in range(len(poly_coefficients)):
    y_learned += w[i] * np.power(x_train, i)
plt.plot(x_train, y_learned, 'r')
plt.show()
